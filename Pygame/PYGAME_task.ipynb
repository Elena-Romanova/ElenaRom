# %%
import pygame as pg
import sys
from random import randint

WIDTH = 600
HEIGHT = 600
FPS = 60

class Basket(pg.sprite.Sprite):
    def __init__(self):
        # Вызовем конструктор родительского класса (Sprite)
        pg.sprite.Sprite.__init__(self)
        # Создаём с помощью клласса Surface поверхность для изображения 
        self.image: pg.Surface = pg.image.load('корзина.png').convert_alpha()
        self.image = pg.transform.scale(self.image, (170, 150)) # задаём новый размер
        # Создаём с помощью клласса Rect объект для взаимодействия с другими объектами
        self.rect: pg.Rect = self.image.get_rect(center = (WIDTH/2, HEIGHT- 80))

    def update(self):
        pass

class Bear(pg.sprite.Sprite):
    def __init__(self):
        # Вызовем конструктор родительского класса (Sprite)
        pg.sprite.Sprite.__init__(self)
        # Создаём с помощью клласса Surface поверхность для изображения 
        self.image: pg.Surface = pg.image.load('медведь.png').convert_alpha()
        self.image = pg.transform.scale(self.image, (100, 100)) # изменяем размер
        # Создаём с помощью клласса Rect объект для взаимодействия с другими объектами
        # при этом рандомим ширину, и указываем высоту, для плавного появления объекта
        self.rect: pg.Rect = self.image.get_rect(center = (randint(50, WIDTH-50), 0 - 50))

    def update(self):
        self.rect.y += 5
        pass

class Game:
    def __init__(self):
        self.game_score = 0
        self.visualize(self.game_score)

    @staticmethod
    def collideBalls(bears, basket, game_score):
        for bear in bears:
            if basket.rect.collidepoint(bear.rect.center):
                if bear.rect.center[1] == basket.rect.top:
                    game_score += 1
                    bear.kill()
        return game_score

    @staticmethod
    def visualize(game_score):
        # инициализируем pygame с помощью команды pygame.init(), которая необходима для использования команд модуля pygame.
        pg.init()
        pg.mixer.init()
        # создаём главную поверхность 
        window = pg.display.set_mode((600, 600))

        # создаём поверхность фон главной поверхности
        background = pg.image.load('фон.jpg').convert()
        # масштабируем фон по размеру главной поверхности
        background = pg.transform.smoothscale(background, window.get_size())
        # прикрепляем поверхность-фон к главной поверхности
        window.blit(background, (0, 0))
        clock = pg.time.Clock()

        # создаём группу для спрайтов и добавляем туда наши классы
        sprites = pg.sprite.Group()
        bear = Bear()
        basket = Basket()
        sprites.add(basket)
        sprites.add(bear)
        bears = []
        bears.append(bear)

        # создаём поверхность для отображения результатов game_score
        f = pg.font.SysFont('arial', 10)

        # обновляем поверхность
        pg.display.update()

        play = True
        new_bear = 0
        while play:
            ''' при первом входе в цикл, в sprites находится экземпляр класса Bear() и Basket() и 
                пока мы не добавим в другой экземпляр этого класса, при выполнении update() 
                будет выполняться update() прописанный в классе '''
            
            for i in pg.event.get():
                if i.type == pg.QUIT:
                    play = False
                    pg.quit() 
                    sys.exit()  
            
            if pg.mouse.get_focused(): # если курсор находится в пределах окна игры
                pos = pg.mouse.get_pos()
                # я создаю экземпляр класса Basket(), меняю его координаты в зависимости от координат курсора, и добаляю его в sprites
                # basket = Basket()
                print(basket.rect.top)
                basket.rect.center = (pos[0], HEIGHT-80)
                # sprites.add(basket)

            # благодаря этому условию, медведи идут постепенно
            new_bear += 1
            if new_bear == 30:
                bear = Bear()
                bears.append(bear)
                sprites.add(bear)
                new_bear = 0
            clock.tick(FPS)    

            # добавляем медведя и корзинку на поверхность, и обновляем фон
            sprites.update()
            window.blit(background, (0, 0))
            sprites.draw(window)

            text = f.render(f"{game_score}", False, (255, 215, 0))
            window.blit(text, (3,590))

            # обновляем всю поверхность после того, как всё было отрисовано            
            pg.display.flip()
            clock.tick(FPS)
            


            game_score = Game.collideBalls(bears, basket, game_score)
            print(game_score)


Game()
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 0
# 445
# 1
# 445
# 2
# 445
# 3
# 445
# 4
# 445
# 5
# 445
# 6
# 445
# 7
# 445
# 8
# 445
# 9
# 445
# 10
# 445
# 11
# 445
# 12
# 445
# 13
# 445
# 14
# 445
# 15
# 445
# 16
# 445
# 17
# 445
# 18
# 445
# 19
# 445
# 20
# 445
# 21
# 445
# 22
# 445
# 23
# 445
# 24
# 445
# 25
# 445
# 26
# 445
# 27
# 445
# 28
# 445
# 29
# 445
# 31
# 445
# 33
# 445
# 35
# 445
# 37
# 445
# 39
# 445
# 41
# 445
# 43
# 445
# 45
# 445
# 47
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 49
# 445
# 50
# 445
# 51
# 445
# 52
# 445
# 53
# 445
# 54
# 445
# 55
# 445
# 56
# 445
# 57
# 445
# 58
# 445
# 59
# 445
# 60
# 445
# 61
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 62
# 445
# 63
# 445
# 64
# 445
# 65
# 445
# 66
# 445
# 67
# 445
# 68
# 445
# 69
# 445
# 70
# 445
# 71
# 445
# 72
# 445
# 73
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 74
# 445
# 75
# 445
# 76
# 445
# 77
# 445
# 78
# 445
# 79
# 445
# 80
# 445
# 82
# 445
# 84
# 445
# 87
# 445
# 89
# 445
# 91
# 445
# 93
# 445
# 95
# 445
# 97
# 445
# 98
# 445
# 99
# 445
# 100
# 445
# 101
# 445
# 102
# 445
# 103
# 445
# 104
# 445
# 105
# 445
# 106
# 445
# 107
# 445
# 108
# 445
# 109
# 445
# 110
# 445
# 111
# 445
# 112
# 445
# 113
# 445
# 115
# 445
# 117
# 445
# 119
# 445
# 121
# 445
# 123
# 445
# 125
# 445
# 127
# 445
# 129
# 445
# 132
# 445
# 134
# 445
# 136
# 445
# 137
# 445
# 140
# 445
# 142
# 445
# 144
# 445
# 146
# 445
# 148
# 445
# 150
# 445
# 152
# 445
# 154
# 445
# 156
# 445
# 158
# 445
# 160
# 445
# 162
# 445
# 164
# 445
# 166
# 445
# 168
# 445
# 170
# 445
# 172
# 445
# 174
# 445
# 177
# 445
# 180
# 445
# 183
# 445
# 186
# 445
# 189
# 445
# 192
# 445
# 195
# 445
# 198
# 445
# 201
# 445
# 204
# 445
# 207
# 445
# 210
# 445
# 213
# 445
# 216
# 445
# 219
# 445
# 222
# 445
# 225
# 445
# 228
# 445
# 231
# 445
# 234
# 445
# 237
# 445
# 240
# 445
# 243
# 445
# 246
# 445
# 249
# 445
# 252
# 445
# 255
# 445
# 258
# 445
# 261
# 445
# 264
# 445
# 269
# 445
# 273
# 445
# 275
# 445
# 276
# 445
# 278
# 445
# 280
# 445
# 282
# 445
# 284
# 445
# 286
# 445
# 288
# 445
# 290
# 445
# 292
# 445
# 294
# 445
# 296
# 445
# 298
# 445
# 300
# 445
# 302
# 445
# 304
# 445
# 306
# 445
# 308
# 445
# 310
# 445
# 312
# 445
# 314
# 445
# 316
# 445
# 318
# 445
# 320
# 445
# 322
# 445
# 324
# 445
# 326
# 445
# 328
# 445
# 331
# 445
# 334
# 445
# 337
# 445
# 340
# 445
# 343
# 445
# 346
# 445
# 349
# 445
# 352
# 445
# 355
# 445
# 358
# 445
# 362
# 445
# 366
# 445
# 370
# 445
# 374
# 378
# 382
# 386
# 390
# 394
# 398
# 402
# 406
# 410
# 414
# 418
# 422
# 426
# 430
# 434
# 438
# 443
# 448
# 453
# 458
# 463
# 468
# 473
# 478
# 483
# 488
# 493
# 498
# 503
# 508
# 513
# 518
# 523
# 528
# 533
# 538
# 543
# 548
# 553
# 558
# 563
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ACER\Desktop\Новая папка\Pygame\PYGAME_task.ipynb Ячейка 1 in <cell line: 130>()
#     <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=125'>126</a>             game_score = Game.collideBalls(bears, basket, game_score)
#     <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=126'>127</a>             print(game_score)
# --> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=129'>130</a> Game()
#
# c:\Users\ACER\Desktop\Новая папка\Pygame\PYGAME_task.ipynb Ячейка 1 in Game.__init__(self)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=37'>38</a> def __init__(self):
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a>     self.game_score = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=39'>40</a>     self.visualize(self.game_score)
#
# c:\Users\ACER\Desktop\Новая папка\Pygame\PYGAME_task.ipynb Ячейка 1 in Game.visualize(game_score)
#     <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=119'>120</a> # обновляем всю поверхность после того, как всё было отрисовано
#     <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=120'>121</a> pg.display.flip()
# --> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=121'>122</a> clock.tick(FPS)
#     <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=125'>126</a> game_score = Game.collideBalls(bears, basket, game_score)
#     <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/Pygame/PYGAME_task.ipynb#W0sZmlsZQ%3D%3D?line=126'>127</a> print(game_score)
#
# KeyboardInterrupt:
