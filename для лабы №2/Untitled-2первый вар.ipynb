# %%
# учитывая уже стощие на доске фигуры, нахожу свободные безопасные клетки
# передаём функции значения: n-количество столбцов и строк; data_fig-спискок координат уже стоящих фигур; 
# svobod_kletki-список, куда будут добавляться свободные безопастные координаты; 
def F_svobod_kletki(n: int, data_fig: list, svobod_kletki: list):
    x=0
    y=0
    while  y<=n:
        while x<=n:            
            koordinata =' '
            for i in data_fig: #беру координаты первой поставленной фигуры и проверяю заходит ли координата (x;y) на поле её удара,
                a=i[0] # х для уже заданной фигуры
                b=i[1] # у для уже заданной фигуры
                
                if ((b>=y>=(b-4) or b<=y<=(b+4)) and (a>=y>=(a-4) or a<=y<=(a+4)) and ((abs(x-y) == abs(a-b)) or ((x+y)==(a+b)))):
                    koordinata ='занята'
                    break #выходим т.к. в этом случае координата нам не подходит
                else:
                    koordinata ='свободна'
            if koordinata == 'свободна':
                svobod_kletki.append([x,y])

            x+=1 #проверяем всю строку
        x=0 
        y+=1 #проверяем все столбцы
    
    return svobod_kletki

# передаём функции значения: n-количество столбцов и строк; l-количество фигур, которые нужно поставить;
# data_fig-спискок координат уже стоящих фигур; svobod_kletki-список, куда будут добавляться 
def check(n: int,l: int, data_fig: list, svobod_kletki: list):
    print('data_fig 6666',data_fig)
    if l==0:
        svobod_kletki = F_svobod_kletki (n, data_fig, svobod_kletki)
        print('выводим')
        print(data_fig)
        #выводим
    else:
        svobod_kletki = F_svobod_kletki (n, data_fig, svobod_kletki)  
        for i in svobod_kletki:        
            check(n,l-1,data_fig + [i[0]],i[1:])

    return '0 '


def main():
    t= open("input.txt", "r+")
    data = t.readlines()

    # убираю знаки табуляции, чтобы не мешали
    for i in range (len(data)):
        if data[i][-1] == '\n':  
            data[i] = data[i][:-1]
    print('полученные данные', data)

    # преобразую список для удобства
    del0 = data[0].split() # количество столбцов и строк
    n = int(del0[0]) # количество строк и столбцов
    l = int(del0[1]) # сколько фигур необходимо расставить
    k = int(del0[2]) # количесвто уже расставленных фигур
    del0=data.pop(0) # теперь в data только кооринаты начальных фигур
    print('нач. координаты',data)
    print(n)
    print(l)
    print(k)

    # уберём пробел для удобства между координатами
    data_fig = []
    for i in range (k):
        data_fig.append(data[i].split())

    # изменим str на int
    for i in data_fig:
        i[0]=int(i[0])
        i[1]=int(i[1])
    print('нач координаты int',data_fig)

    x=0 
    y=0
    svobod_kletki = []
                        
    rez = check(n, l, data_fig, svobod_kletki)  
    print(rez)

if __name__=="__main__":
    main()
# Out:
# полученные данные ['20 2 1', '9 9']
# нач. координаты ['9 9']
# 20
# 2
# 1
# нач координаты int [[9, 9]]
# data_fig 6666 [[9, 9]]
# data_fig 6666 [[9, 9], 0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ACER\Desktop\Новая папка\для лабы №2\Untitled-2первый вар.ipynb Ячейка 1 in <cell line: 84>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=81'>82</a>     print(rez)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=83'>84</a> if __name__=="__main__":
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=84'>85</a>     main()
#
# c:\Users\ACER\Desktop\Новая папка\для лабы №2\Untitled-2первый вар.ipynb Ячейка 1 in main()
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=77'>78</a> y=0
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=78'>79</a> svobod_kletki = []
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=80'>81</a> rez = check(n, l, data_fig, svobod_kletki)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=81'>82</a> print(rez)
#
# c:\Users\ACER\Desktop\Новая папка\для лабы №2\Untitled-2первый вар.ipynb Ячейка 1 in check(n, l, data_fig, svobod_kletki)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a>     svobod_kletki = F_svobod_kletki (n, data_fig, svobod_kletki)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=38'>39</a>     for i in svobod_kletki:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=39'>40</a>         check(n,l-1,data_fig + [i[0]],i[1:])
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=41'>42</a> return '0 '
#
# c:\Users\ACER\Desktop\Новая папка\для лабы №2\Untitled-2первый вар.ipynb Ячейка 1 in check(n, l, data_fig, svobod_kletki)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=30'>31</a> print('data_fig 6666',data_fig)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a> if l==1:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=32'>33</a>     svobod_kletki = F_svobod_kletki (n, data_fig, svobod_kletki)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=33'>34</a>     print('выводим')
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=34'>35</a>     print(data_fig)
#
# c:\Users\ACER\Desktop\Новая папка\для лабы №2\Untitled-2первый вар.ipynb Ячейка 1 in F_svobod_kletki(n, data_fig, svobod_kletki)
#       <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> koordinata =' '
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> for i in data_fig: #беру координаты первой поставленной фигуры и проверяю заходит ли координата (x;y) на поле её удара,
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     a=i[0] # х для уже заданной фигуры
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     b=i[1] # у для уже заданной фигуры
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/%D0%B4%D0%BB%D1%8F%20%D0%BB%D0%B0%D0%B1%D1%8B%20%E2%84%962/Untitled-2%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9%20%D0%B2%D0%B0%D1%80.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a>     if ((b>=y>=(b-4) or b<=y<=(b+4)) and (a>=y>=(a-4) or a<=y<=(a+4)) and ((abs(x-y) == abs(a-b)) or ((x+y)==(a+b)))):
#
# TypeError: 'int' object is not subscriptable

# %%
#с РАЗДЕЛЕНИЕМ НА ФУНКЦИИ

# учитывая уже стощие на доске фигуры, нахожу свободные безопасные клетки
# передаём функции значения: n-количество столбцов и строк; data_fig-спискок координат уже стоящих фигур; 
# svobod_kletki-список, куда будут добавляться свободные безопастные координаты; 
def F_svobod_kletki(n: int, data_fig: list, svobod_kletki: list):
    x=0
    y=0
    while  y<=n:
        while x<=n:            
            koordinata =' '
            for i in data_fig: #беру координаты первой поставленной фигуры и проверяю заходит ли координата (x;y) на поле её удара,
                a=i[0] # х для уже заданной фигуры
                b=i[1] # у для уже заданной фигуры
                
                if ((y >= (b-4) or y <= (b+4)) and (x >= (a-4) or x <= (a+4))) and ((abs(x-y) == abs(a-b)) or ((x+y)==(a+b))):
                    koordinata ='занята'
                    break #выходим т.к. в этом случае координата нам не подходит
                else:
                    koordinata ='свободна'
            if koordinata == 'свободна':
                svobod_kletki.append([x,y])

            x+=1 #проверяем всю строку
        x=0 
        y+=1 #проверяем все столбцы

    return svobod_kletki

# передаём функции значения: n-количество столбцов и строк; l-количество фигур, которые нужно поставить;
# data_fig-спискок координат уже стоящих фигур; svobod_kletki-список, куда будут добавляться 
def check(n: int,l: int, data_fig: list, svobod_kletki: list):
    if l==0:
        print('выводим')
        #выводим
    else:
        svobod_kletki = F_svobod_kletki (n, data_fig, svobod_kletki)      
        d=svobod_kletki.pop(0)
        data_fig.append(d)          
        check(n,l-1,data_fig,svobod_kletki)

    return data_fig


def main():
    t= open("input.txt", "r+")
    data = t.readlines()

    # убираю знаки табуляции, чтобы не мешали
    for i in range (len(data)):
        if data[i][-1] == '\n':  
            data[i] = data[i][:-1]
    print('полученные данные', data)

    # преобразую список для удобства
    del0 = data[0].split() # количество столбцов и строк
    n = int(del0[0]) # количество строк и столбцов
    l = int(del0[1]) # сколько фигур необходимо расставить
    k = int(del0[2]) # количесвто уже расставленных фигур
    del0=data.pop(0) # теперь в data только кооринаты начальных фигур
    print('нач. координаты',data)
    print(n)
    print(l)
    print(k)

    # уберём пробел для удобства между координатами
    data_fig = []
    for i in range (k):
        data_fig.append(data[i].split())

    # изменим str на int
    for i in data_fig:
        i[0]=int(i[0])
        i[1]=int(i[1])
    print('нач координаты int',data_fig)

    x=0 
    y=0
    svobod_kletki = []
                        
    rez = check(n, l, data_fig, svobod_kletki)  
    print(rez)

if __name__=="__main__":
    main()
# Out:
# полученные данные ['20 2 1', '9 9']
# нач. координаты ['9 9']
# 20
# 2
# 1
# нач координаты int [[9, 9]]
# выводим
# [[9, 9], [1, 0], [2, 0]]

# %%
#БЕЗ РАЗДЕЛЕНИЯ НА ФУНКЦИИ

# передаём функции значения: n-количество столбцов и строк; l-количество фигур, которые нужно поставить;
# data_fig-спискок координат уже стоящих фигур; svobod_kletki-список, куда будут добавляться 
def check(n: int,l: int, data_fig: list, svobod_kletki: list):
    x=0
    y=0
    if l==0:
        x=0
    else:
        while  y<=n:
            while x<=n:            
                koordinata =' '
                for i in data_fig: #беру координаты первой поставленной фигуры и проверяю заходит ли координата (x;y) на поле её удара,
                    a=i[0] # х для уже заданной фигуры
                    b=i[1] # у для уже заданной фигуры
                    
                    if ((y >= (b-4) or y <= (b+4)) and (x >= (a-4) or x <= (a+4))) and ((abs(x-y) == abs(a-b)) or ((x+y)==(a+b))):
                        koordinata ='занята'
                        break #выходим т.к. в этом случае координата нам не подходит
                    else:
                        koordinata ='свободна'
                if koordinata == 'свободна':
                    svobod_kletki.append([x,y])

                x+=1 #проверяем всю строку
            x=0 
            y+=1 #проверяем все столбцы
        
        #for i in svobod_kletki:
        d=svobod_kletki.pop(0)
        data_fig.append(d)          
        check(n,l-1,data_fig,svobod_kletki)

    return data_fig

def main():
    t= open("input.txt", "r+")
    data = t.readlines()

    # убираю знаки табуляции, чтобы не мешали
    for i in range (len(data)):
        if data[i][-1] == '\n':  
            data[i] = data[i][:-1]
    print('полученные данные', data)

    # преобразую список для удобства
    del0 = data[0].split() # количество столбцов и строк
    n = int(del0[0]) # количество строк и столбцов
    l = int(del0[1]) # сколько фигур необходимо расставить
    k = int(del0[2]) # количесвто уже расставленных фигур
    del0=data.pop(0) # теперь в data только кооринаты начальных фигур
    print('нач. координаты',data)
    print(n)
    print(l)
    print(k)

    # уберём пробел для удобства между координатами
    data_fig = []
    for i in range (k):
        data_fig.append(data[i].split())
    print('data_fig',data_fig)

    # изменим str на int
    for i in data_fig:
        i[0]=int(i[0])
        i[1]=int(i[1])
    print('data_fig111111',data_fig)

    x=0 
    y=0
    svobod_kletki = []
                        
    rez = check(n, l, data_fig, svobod_kletki)  
    print(rez)

if __name__=="__main__":
    main()
# Out:
# полученные данные ['20 2 1', '9 9']
# нач. координаты ['9 9']
# 20
# 2
# 1
# data_fig [['9', '9']]
# data_fig111111 [[9, 9]]
# [[9, 9], [1, 0], [2, 0]]
